# %% [markdown]
# # 라이브러리

# %%
! pip3 install koreanize_matplotlib
# Out:
# Requirement already satisfied: koreanize_matplotlib in /usr/local/lib/python3.11/dist-packages (0.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %% [markdown]
# # 정의

# %% [markdown]
# 📊 퍼널 단계 정의 (채용 플랫폼 기준)
# 1. 랜딩 단계 (Landing / 탐색 진입)
#     - 관련 URL: home, search, suggest, jobs, companies, people
#     - 목적: 플랫폼에 들어와서 정보를 둘러보기 시작함.
#
# 2. 정보 탐색 단계 (View Details)
#     - 관련 URL: jobs/job_id, companies/company_id, people/id, jobs/id/other_jobs
#     - 목적: 개별 채용공고나 기업/인물의 상세 정보 열람
#
# 3. 행동 유도 단계 (Engagement / Action Intent)
#     - 관련 URL: continue, signup, email_verify, verify_phone, setting
#     - 목적: 회원가입을 시작하거나, 지원을 위한 절차 진행
#
# 4. 지원 단계 (Apply)
#     - 관련 URL: apply, applications/job_id, @user_id?action=request_approval_complete
#     - 목적: 실제 채용공고에 지원하는 행동
#
# 5. 완료/성과 단계 (Success / Conversion)
#     - 관련 URL: password_reset, help, zip_code, admin, app, pricing
#     - 목적: 전환 이후 지속 이용 또는 추가 행동을 보임

# %% [markdown]
# 🔁 전환/이탈률 분석 설계
# 각 단계의 유입 사용자 수를 기반으로:
#
# |퍼널 단계|방문자 수|전환률 (%)|이탈률 (%)|
# |---|---|---|---|
# |랜딩|A|-|((A - B) / A) * 100|
# |정보 탐색|B|(B / A) * 100|((B - C) / B) * 100|
# |행동 유도|C|(C / B) * 100|((C - D) / C) * 100|
# |지원|D|(D / C) * 100|((D - E) / D) * 100|
# |전환 완료|E|(E / D) * 100|-|

# %% [markdown]
# # 데이터 불러오기

# %%
log_2022_path = "/content/drive/MyDrive/코드잇_데이터분석_6기/프로젝트/데이터 분석 중급 프로젝트_1/원본 데이터/주제 1. 국내 채용시장 및 채용 플랫폼 이용패턴 분석/log_2022.csv"
log_2022_df = pd.read_csv(log_2022_path)
log_2022_df.head(2)
# Out:
#    Unnamed: 0                             user_uuid  \
# 0           0  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 1           1  8a7e70cd-1630-4a8a-8303-0706af3a7908
#
#                                             URL  \
# 0  api/search/language?name=한국어&_=1655915651225
# 1                               api/signup/form
#
#                         timestamp        date  response_code method
# 0  2022-06-22 16:42:48.247454 UTC  2022-06-23            200    GET
# 1  2022-06-22 16:19:07.770741 UTC  2022-06-23            200   POST

# %%
# 1. UTC 제거
log_2022_df["timestamp_clean"] = log_2022_df["timestamp"].str.replace(" UTC", "", regex=False)

# 2. datetime으로 변환
log_2022_df["timestamp_clean"] = pd.to_datetime(
    log_2022_df["timestamp_clean"],
    format='%Y-%m-%d %H:%M:%S.%f',
    errors='coerce'
)

# 3. NaT가 생긴 경우, 포맷이 다른 문자열을 다시 처리 (마이크로초 없는 경우 등)
mask_failed = log_2022_df["timestamp_clean"].isna()
log_2022_df.loc[mask_failed, "timestamp_clean"] = pd.to_datetime(
    log_2022_df.loc[mask_failed, "timestamp"].str.replace(" UTC", "", regex=False),
    format="%Y-%m-%d %H:%M:%S",
    errors="coerce"
)

# 4. 정리
log_2022_df["timestamp"] = log_2022_df["timestamp_clean"]
log_2022_df.drop(columns="timestamp_clean", inplace=True)

# %%
# UTM 파라미터 확인
log_2022_df[log_2022_df["URL"].str.contains("utm_", case=False, na=False)]
# Out:
#           Unnamed: 0                             user_uuid  \
# 20                20  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 129              129  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 168              168  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 255              255  207a8876-2a6c-4137-9347-476ce719c541
# 287              287  207a8876-2a6c-4137-9347-476ce719c541
# ...              ...                                   ...
# 10054105    10054105  d491cf04-1408-4f1a-bc14-3dccccdc05a4
# 10054107    10054107  b26bf8fc-58d6-4a7c-8dfa-b05c37bc3570
# 10054113    10054113  a4295723-f94c-4f3a-8a48-37c1b8e4850a
# 10054118    10054118  d2b90cda-7e0d-454f-8a64-070048551e14
# 10054119    10054119  d2b90cda-7e0d-454f-8a64-070048551e14
#
#                                                         URL  \
# 20        @user_id?utm_source=notification&utm_medium=em...
# 129       r?type=experience_verify&c=87c2170d-c7e5-4bb8-...
# 168       jobs/id/id_title?utm_campaign=google_jobs_appl...
# 255       @user_id?utm_source=notification&utm_medium=em...
# 287       @user_id?utm_source=notification&utm_medium=em...
# ...                                                     ...
# 10054105                    setting?utm_source=notification
# 10054107  setting?utm_source=notification&utm_medium=ema...
# 10054113  jobs/id/id_title?utm_campaign=google_jobs_appl...
# 10054118  setting?utm_source=notification&utm_medium=ema...
# 10054119  setting?utm_source=notification&utm_medium=ema...
#
#                           timestamp        date  response_code method
# 20       2022-06-23 16:35:25.501568  2022-06-24            200    GET
# 129      2022-06-22 16:26:09.919652  2022-06-23            302    GET
# 168      2022-06-22 16:21:07.392774  2022-06-23            200    GET
# 255      2022-06-22 22:10:33.194900  2022-06-23            200    GET
# 287      2022-06-02 22:14:13.023414  2022-06-03            200    GET
# ...                             ...         ...            ...    ...
# 10054105 2022-08-19 14:45:52.762488  2022-08-19            200    GET
# 10054107 2022-07-11 18:19:19.566660  2022-07-12            200    GET
# 10054113 2022-02-10 06:55:11.196278  2022-02-10            200    GET
# 10054118 2022-07-27 01:47:23.149828  2022-07-27            200    GET
# 10054119 2022-07-28 00:34:34.781394  2022-07-28            200    GET
#
# [70609 rows x 7 columns]

# %%
# UTM 파라미터 제거
from urllib.parse import urlparse

def remove_query_params(url):
    try:
        return urlparse(url).path.lower()
    except:
        return str(url).lower()

log_2022_df["clean_url"] = log_2022_df["URL"].apply(remove_query_params)

# %% [markdown]
# # 퍼널 단계 부여

# %%
# clean_url 만들기
log_2022_df["clean_url"] = log_2022_df["clean_url"].str.lower()

# 퍼널 단계 정의 (4번째 수정함...)
# funnel_stage를 나누는 과정에서 조건이 누락됐거나 너무 좁게 정의됐을 경우 (jobs/ 대신 api/jobs/job_title처럼 되어 있음)
funnel_stages = {
    "landing": ["home", "search", "suggest", "jobs", "companies", "people"],
    "view_details": ["job", "company", "people", "other_jobs"],
    "engagement": ["continue", "signup", "email_verify", "verify_phone", "setting"],
    "apply": ["apply", "applications", "request_approval_complete", "@user_id"],
    "converted": ["password_reset", "help", "zip_code", "admin", "app", "pricing"]
}

# 퍼널 단계 부여 함수
def assign_funnel_stage(url):
    url = str(url).lower()
    for stage, keywords in funnel_stages.items():
        if any(k in url for k in keywords):
            return stage
    return "other"

# funnel_stage 컬럼 생성
log_2022_df["funnel_stage"] = log_2022_df["clean_url"].apply(assign_funnel_stage)

log_2022_df.head()
# Out:
#    Unnamed: 0                             user_uuid  \
# 0           0  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 1           1  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 2           2  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 3           3  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 4           4  8a7e70cd-1630-4a8a-8303-0706af3a7908
#
#                                                  URL  \
# 0       api/search/language?name=한국어&_=1655915651225
# 1                                    api/signup/form
# 2                              api/users/id/template
# 3                              api/users/id/template
# 4  api/users/id/phone/verify/template?_=165591488...
#
#                    timestamp        date  response_code method  \
# 0 2022-06-22 16:42:48.247454  2022-06-23            200    GET
# 1 2022-06-22 16:19:07.770741  2022-06-23            200   POST
# 2 2022-06-22 16:41:54.449837  2022-06-23            200   POST
# 3 2022-06-23 02:53:47.040932  2022-06-23            200   POST
# 4 2022-06-22 16:21:58.154299  2022-06-23            200    GET
#
#                             clean_url funnel_stage
# 0                 api/search/language      landing
# 1                     api/signup/form   engagement
# 2               api/users/id/template        other
# 3               api/users/id/template        other
# 4  api/users/id/phone/verify/template        other

# %% [markdown]
# ## other 단계 제외

# %%
# other 행만 모아 새로운 데이터프레임 생성
out_of_stage_df = log_2022_df[log_2022_df["funnel_stage"] == "other"]
out_of_stage_df.head()
# Out:
#    Unnamed: 0                             user_uuid  \
# 2           2  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 3           3  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 4           4  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 5           5  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 8           8  8a7e70cd-1630-4a8a-8303-0706af3a7908
#
#                                                  URL  \
# 2                              api/users/id/template
# 3                              api/users/id/template
# 4  api/users/id/phone/verify/template?_=165591488...
# 5  api/users/id/education/template?type=apply&_=1...
# 8            api/users/id/experience/form?type=apply
#
#                    timestamp        date  response_code method  \
# 2 2022-06-22 16:41:54.449837  2022-06-23            200   POST
# 3 2022-06-23 02:53:47.040932  2022-06-23            200   POST
# 4 2022-06-22 16:21:58.154299  2022-06-23            200    GET
# 5 2022-06-22 16:25:42.416476  2022-06-23            200    GET
# 8 2022-06-22 16:34:11.692417  2022-06-23            200   POST
#
#                             clean_url funnel_stage
# 2               api/users/id/template        other
# 3               api/users/id/template        other
# 4  api/users/id/phone/verify/template        other
# 5     api/users/id/education/template        other
# 8        api/users/id/experience/form        other

# %%
# other 행을 제외한 나머지
log_df = log_2022_df[log_2022_df["funnel_stage"] != "other"]
log_df.head()
# Out:
#     Unnamed: 0                             user_uuid  \
# 0            0  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 1            1  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 6            6  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 7            7  8a7e70cd-1630-4a8a-8303-0706af3a7908
# 10          10  8a7e70cd-1630-4a8a-8303-0706af3a7908
#
#                                                   URL  \
# 0        api/search/language?name=한국어&_=1655915651225
# 1                                     api/signup/form
# 6   api/search/people/job_title?name=data en&_=165...
# 7                     api/search/specialty?name=bento
# 10                                            setting
#
#                     timestamp        date  response_code method  \
# 0  2022-06-22 16:42:48.247454  2022-06-23            200    GET
# 1  2022-06-22 16:19:07.770741  2022-06-23            200   POST
# 6  2022-06-22 16:20:10.851840  2022-06-23            200    GET
# 7  2022-06-22 16:33:43.647159  2022-06-23            200    GET
# 10 2022-06-26 08:11:33.254330  2022-06-26            200    GET
#
#                       clean_url funnel_stage
# 0           api/search/language      landing
# 1               api/signup/form   engagement
# 6   api/search/people/job_title      landing
# 7          api/search/specialty      landing
# 10                      setting   engagement

# %% [markdown]
# # 각 단계별 사용자 수

# %% [markdown]
# UTM 파라미터 제거 전
#
# |단계|사용자 수|
# |---|---|
# |landing|15934|
# |view_details|6812|
# |engagement|9872|
# |apply|15776|
# |success|7663|
#
# -> 제거 후 결과와 큰 차이 없음

# %%
# 각 퍼널 단계별 고유 사용자 수 계산
funnel_user_counts = log_df.groupby("funnel_stage")["user_uuid"].nunique()

# 순서를 맞춰 정렬
funnel_order = ["landing", "view_details", "engagement", "apply", "converted"]
funnel_user_counts = funnel_user_counts.reindex(funnel_order).fillna(0).astype(int)

# A, B, C, D, E에 할당
A, B, C, D, E = funnel_user_counts.values

# 단계별 사용자 수를 데이터프레임으로 정리
stage_user_counts_df = pd.DataFrame({
    "단계": ["landing", "view_details", "engagement", "apply", "converted"],
    "사용자 수": [A, B, C, D, E]
})

stage_user_counts_df
# Out:
#              단계  사용자 수
# 0       landing  15842
# 1  view_details   5993
# 2    engagement  10691
# 3         apply  15747
# 4     converted   7662

# %% [markdown]
# # 전환률 계산

# %%
funnel_metrics = {
    "단계": ["landing", "view_details", "engagement", "apply", "converted"],
    "방문자 수": [A, B, C, D, E],
    "전환률 (%)": ["-", round((B / A) * 100, 2) if A else 0, round((C / B) * 100, 2) if B else 0, round((D / C) * 100, 2) if C else 0, round((E / D) * 100, 2) if D else 0],
    "이탈률 (%)": [round(((A - B) / A) * 100, 2) if A else "-", round(((B - C) / B) * 100, 2) if B else "-", round(((C - D) / C) * 100, 2) if C else "-", round(((D - E) / D) * 100, 2) if D else "-", "-"]
}

funnel_df = pd.DataFrame(funnel_metrics)
funnel_df
# Out:
#              단계  방문자 수 전환률 (%) 이탈률 (%)
# 0       landing  15842       -   62.17
# 1  view_details   5993   37.83  -78.39
# 2    engagement  10691  178.39  -47.29
# 3         apply  15747  147.29   51.34
# 4     converted   7662   48.66       -

# %% [markdown]
# # 인사이트

# %% [markdown]
# ## Landing -> View Details

# %% [markdown]
# - 전환률: 42.75%
# - 이탈률: 57.25%
#     - 약 절반 이상이 상세 내용을 보지 않고 떠남 -> 랜딩 페이지 품질 또는 추천 콘텐츠/검색 결과 적합성 문제

# %% [markdown]
# ## 2. View Details -> Engagement

# %% [markdown]
# - 전환률: 144.92% (비정상적으로 높음)
#     - 이는 단계 중복 또는 URL 라벨링 오류 가능성 있음
#         - 사용자가 View 없이 바로 Signup한 경우
#         - Engagement URL이 너무 포괄적하게 잡혀 있을 가능성 있음

# %% [markdown]
# ## 3. Engagement -> Apply

# %% [markdown]
# - 전환률: 159.81%
#     - 역시 중간 단계가 일부 사용자에게 스킵되었거나, Apply로 바로 가는 구조

# %% [markdown]
# ## 4. Apply -> Success

# %% [markdown]
# - 전환률: 48.57%
#     - 실제 전환까지 이어진 비율로 괜찮은 수치
#     - 절반 정도는 지원 후 추가 행동 없이 이탈
#     - 알림, 후속 안내 UX 강화 필요

# %% [markdown]
# ## 추천 액션

# %% [markdown]
# - 퍼널 단계 정의 정교화
#     - view_details와 engagement 사이 흐름 점검
#     - 혹시 중복이 있거나 불필요한 포함 키워드가 있는지 확인
#
# - 비정상 전환률(100% 이상)
#     - 중복 방문자, 여러 단계 누락된 사용자 흐름을 따로 분석 필요
#
# - 실 사용자 흐름 시각화
#     - Sankey Diagram이나 Funnel Chart로 각 사용자 흐름 시각화
#
# - 세그먼트별 퍼널 분석
#     - 예: job_seeker, employer 각각의 퍼널 전환율 비교 -> 맞춤 전략 가능

# %% [markdown]
# # 시각화

# %% [markdown]
# ## Sankey Diagram (Plotly)

# %%
import plotly.graph_objects as go

# 사용자별 퍼널 단계 시퀀스 정리
user_funnel = log_df.sort_values(by=["user_uuid", "timestamp"])
user_funnel = user_funnel.groupby("user_uuid")["funnel_stage"].apply(lambda x: list(dict.fromkeys(x)))  # 중복 제거

# 전이 단계 추출
from collections import Counter
transitions = Counter()

for stages in user_funnel:
    for i in range(len(stages)-1):
        transitions[(stages[i], stages[i+1])] += 1

# 고유 단계 리스트
labels = list({s for pair in transitions.keys() for s in pair})
label_index = {k: i for i, k in enumerate(labels)}

# 출발, 도착, 값 정의
source = [label_index[src] for src, tgt in transitions.keys()]
target = [label_index[tgt] for src, tgt in transitions.keys()]
value = list(transitions.values())

# Sankey 그리기
fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=labels
    ),
    link=dict(
        source=source,
        target=target,
        value=value
    ))])

fig.update_layout(title_text="사용자 퍼널 단계 이동 Sankey Diagram", font_size=12)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c673732f-c677-4ab0-919d-51c8ceabe902" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c673732f-c677-4ab0-919d-51c8ceabe902")) {                    Plotly.newPlot(                        "c673732f-c677-4ab0-919d-51c8ceabe902",                        [{"link":{"source":[0,2,4,3,0,3,2,2,0,3,4,4,3,1,4,0,1,1,2,1],"target":[2,4,3,1,4,0,1,0,3,4,1,0,2,3,2,1,2,4,3,0],"value":[3801,1081,4286,970,1756,8120,1791,663,4867,1626,1536,1337,1529,594,1135,1333,815,642,369,631]},"node":{"label":["apply","view_details","converted","landing","engagement"],"line":{"color":"black","width":0.5},"pad":15,"thickness":20},"type":"sankey"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %% [markdown]
# ## Funnel Chart (단계별 전환 시각화)

# %%
import plotly.express as px

stage_user_counts_df = pd.DataFrame({
    "funnel_stage": ["landing", "view_details", "engagement", "apply", "converted"],
    "users": [A, B, C, D, E]
})

fig = px.funnel(stage_user_counts_df, x='users', y='funnel_stage', title="사용자 퍼널 단계별 전환")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f4938428-aeda-4459-8636-0a4989446f7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4938428-aeda-4459-8636-0a4989446f7d")) {                    Plotly.newPlot(                        "f4938428-aeda-4459-8636-0a4989446f7d",                        [{"hovertemplate":"users=%{x}\u003cbr\u003efunnel_stage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","orientation":"h","showlegend":false,"x":[15842,5993,10691,15747,7662],"xaxis":"x","y":["landing","view_details","engagement","apply","converted"],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpo ...

# %% [markdown]
# # 추가

# %% [markdown]
# ## UTM 파라미터 제거 전 후 결과가 동일한 이유

# %% [markdown]
# 1. UTM이 포함된 URL은 대부분 중복 방문일 가능성 있음
# - utm_ 파라미터가 붙는 URL은 보통 마케팅 채널을 통한 유입 추적이 목적이기 때문
#     - 기존 사용자가 여러 번 들어올 때 다른 utm_이 붙어서 같은 페이지를 반복 방문하는 경우가 많음
#     - 퍼널 분석에서는 user_uuid 기준으로 고유 사용자 수를 세기 때문에, 똑같은 사람이 여러 번 utm 붙은 URL로 들어와도 1명으로만 집계됨
#     - 즉, 전체 퍼널 흐름의 경로 자체를 바꾸지 않았기 때문에 전환률은 그대로일 수 있음

# %% [markdown]
# 2. 쿼리스트링을 제거해도 퍼널 분류 기준 키워드가 동일하게 인식됨
# - 퍼널 분류 함수는 쿼리스트링을 보지 않고 경로(path)만으로 분류했기 때문에, UTM 제거 여부와 관계없이 같은 퍼널 단계로 인식

# %% [markdown]
# 3. 쿼리 제거 전과 후의 clean_url 값이 이미 같았던 경우가 많음
# - URL을 쿼리까지 포함한 전체 문자열로 사용한 게 아니라, 퍼널 분류에 쓰기 전에 이미 .str.lower() 같은 걸 써서 경로만 추출한 값들과 비교했다면, 이미 분석이 경로 중심으로 되어 있었기 때문에 UTM 파라미터 제거는 이미 반영되어 있었던 거나 마찬가지였을 수 있음

# %% [markdown]
# ## 전환률 계산 적절한가?

# %% [markdown]
# - 퍼널 전환률은 이전 단계 대비 다음 단계로 몇 %의 사용자가 넘어갔는지 확인
#     - 예시
#         - A (landing): 10,000명
#         - B (view_details): 6,000명
#         - ```전환률 = B/A X 100 = 6,000/10,000 X 100 = 60%```
#             - landing한 사람 중 60%가 view_details 단계로 넘어감

# %% [markdown]
# - 주의할 점
#     - 해당 계산법은 퍼널 구조가 선형적일 때 가장 잘 들어맞음
#     - 사용자가 중간 단계를 건너뛸 수 있는 비선형적 구조일 때는
#     - 전환률이 100%를 넘어가거나, 해석의 차이가 발생할 수 있음
#         - 퍼널을 유연하게 해석할 필요 있음
#             - 예시) 전환률이 100%를 넘으면 이전 단계를 건너뛰고 해당 단계로 유입된 사용자가 있다는 뜻
#         - 따라서 해석할 때 사용자 흐름을 시각화(Sankey 등)해서 보조적으로 파악하는 게 중요

# %% [markdown]
# ## 이탈률이 음수로 나오는 경우

# %% [markdown]
# - 이탈률이 음수로 나온다는 건 원래 개념적으로는 잘못된 상황
# - 데이터나 계산 방식에 따라 나올 수 있는 특이 케이스 중 하나

# %% [markdown]
# ```이탈률 = ((이전 단계 방문자 수 - 현재 단계 방문자 수) / 이전 단계 방문자 수) * 100```
#
# - 현재 단계의 사용자 수가 이전 단계보다 많아지는 경우 이탈률이 음수가 됨

# %% [markdown]
# - 유저가 퍼널을 건너뛰고 들어온 경우
#     - 어떤 유저가 검색(landing)을 하지 않고 바로 apply 페이지로 접근
#     - 이럴 경우 이전 단계에 기록되지 않고도 다음 단계에서 활동
#
# - 퍼널 단계 분류 로직의 오류
#     - URL이 잘못 분류되어, 특정 단계에 사용자 수가 실제보다 적게 잡히는 경우
#
# - 이벤트 중복/로깅 시점의 문제
#     - 로그가 제대로 시간 순서대로 정렬되지 않았거나
#     - 이벤트가 잘못 중복 기록되어 다음 단계 유입이 과도하게 잡힘
#
# - 사용자 세션 구분 오류
#     - 여러 세션 또는 여러 사용자의 활동이 섞여버려 잘못 카운트됨

# %% [markdown]
# ### 보정 아이디어

# %% [markdown]
# - 퍼널 단계를 순서 기준으로 필터링해서, 이전 단계보다 이후 단계에 있는 사용자만 포함
# - 로그 시간 순서를 보장 (sort_values(by=["user_uuid", "timestamp"]))
# - 중복 제거 또는 고유 세션 기반 분석
# - 퍼널 정의/분류를 재점검 (URL 패턴 누락 체크)

# %% [markdown]
# # 특정 유저 하나만 확인

# %%
log_2022_df["user_uuid"].unique()
# Out:
# array(['8a7e70cd-1630-4a8a-8303-0706af3a7908',
#        '207a8876-2a6c-4137-9347-476ce719c541',
#        'd7c84302-545f-4714-bcd1-0cc4328a0f89', ...,
#        'f9387b22-2d7d-4267-8671-2279e2d784b9',
#        '849ff1bb-6280-46f4-baaa-71d1d0796b5b',
#        '940b883f-a385-416c-94e2-b5604a78506c'], dtype=object)

# %%
user_1 = log_2022_df[log_2022_df["user_uuid"] == "207a8876-2a6c-4137-9347-476ce719c541"]

user_1["URL"].unique()
# Out:
# array(['api/users/id/template', 'search?keywords=생물정보학', 'suggest?q=생물',
#        'suggest?q=생', 'search?keywords=마이크로바이옴', 'suggest?q=',
#        'companies/company_id', 'api/search/template?keywords=마이크로바이옴&q=',
#        'api/companies/id/view', 'api/search/template?keywords=@지니너스&q=',
#        'api/jobs/job_title?keywords=bioinformatics&page=&q=',
#        '@user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_342499_profile',
#        'companies/company_id/jobs', 'suggest?q=생물정보학', 'suggest?q=ㅅ',
#        'suggest?q=생물ㅈ', 'suggest?q=마이크로바이옴', 'suggest?q=김',
#        'suggest?q=김ㅁ', 'api/people/template?keywords=김민재&page=&q=',
#        'api/search/template?keywords=bioninformatics&q=',
#        'suggest?q=bioi', 'suggest?q=bioninforma', nan, 'suggest?q=bioin',
#        'suggest?q=ㅇ', '@user_id',
#        'api/search/template?keywords=bioinformatics&q=',
#        'api/jobs/id/other_jobs?offset=0&limit=5', 'people?company=24720',
#        'suggest?q=b', 'signup/step1/name',
#        'search?keywords=bioinformatics', 'suggest?q=bioinform',
#        '@user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_338683_profile',
#        '@user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_384600_profile',
#        'suggest?q=bi', 'jobs/id/id_title', 'suggest?q=bioinformatics',
#        '@user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_412864_profile',
#        'suggest?q=새', 'search', 'api/search/template?q=',
#        'suggest?q=@wlslsj', 'suggest?q=@마크로젠', 'people?company=129582',
#        'suggest?q=docker', 'suggest?q=@지니너스', 'suggest?q=@a',
#        'suggest?q=생물정ㅂ', 'suggest?q=기', 'suggest?q=김민재', 'suggest?q=사',
#        'suggest?q=W', 'suggest?q=bioinforma',
#        'search?keywords=bioninformatics', 'suggest?q=bio', 'jobs',
#        'suggest?q=생물정ㅂㆍ', 'api/search/template?keywords=김민재&q=',
#        '@user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_415458_profile',
#        'api/search/template?keywords=생물정보학&q=', 'suggest?q=생ㅁ',
#        'suggest?q=생물정보', 'api/companies/id/member_list?offset=6',
#        'search?keywords=김민재', 'search?keywords=@마크로젠', 'suggest?q=@ㅈ',
#        'api/companies/id/member_list?oneline=1&offset=3',
#        'suggest?q=bioninform',
#        '@user_id/undefined?offset=undefined&_=1650015535862',
#        'suggest?q=bioinfor', 'api/people/template?company=24720&page=&q=',
#        'suggest?q=bioinfo', 'api/search/template?keywords=지니너스&q=',
#        'suggest?q=bion', 'suggest?q=bionin', 'suggest?q=bioninformatics',
#        'signup', 'suggest?q=bioinformat', 'suggest?q=지니너스', 'suggest?q=ㅠ',
#        'api/jobs/job_title?keywords=bioinformatics\\&page=&q=',
#        'api/jobs/job_title?page=&q=', 'suggest?q=@',
#        'search?keywords=@지니너스',
#        '@user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_420864_profile',
#        'suggest?q=생물저', 'api/search/template?keywords=김나영&q=',
#        'suggest?q=김나영', 'search?keywords=김나영', 'people?keywords=김민재&q=',
#        'suggest?q=생물정',
#        '@user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_425596_profile',
#        'suggest?q=ㅁ', 'suggest?q=bioni',
#        'api/search/template?keywords=@마크로젠&q=', 'search?keywords=지니너스',
#        'suggest?q=bioninfor', 'suggest?q=bionino', 'signup/detail',
#        'api/search/template?keywords=docker&q=', 'search?keywords=docker',
#        'suggest?q=@akzm',
#        '@user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_375943_profile',
#        'api/people/template?company=129582&page=&q='], dtype=object)

# %%
pd.set_option('display.max_rows', None)        # 행 제한 없음
pd.set_option('display.max_columns', None)     # 열 제한 없음
pd.set_option('display.width', None)           # 가로 너비 제한 없음
pd.set_option('display.max_colwidth', None)    # 열 내용 길이 제한 없음

user_1_sorted = user_1.sort_values(by="timestamp").reset_index(drop=True)

user_1_sorted[["timestamp", "URL"]]
# Out:
#                      timestamp  \
# 0   2022-01-06 02:03:30.711295
# 1   2022-01-06 02:03:33.559005
# 2   2022-01-06 02:04:04.943259
# 3   2022-01-06 02:04:07.581707
# 4   2022-02-07 04:47:04.417295
# 5   2022-02-07 04:47:06.717872
# 6   2022-02-07 04:47:18.378761
# 7   2022-02-07 04:47:20.243449
# 8   2022-02-07 04:47:21.915613
# 9   2022-02-07 04:47:22.837149
# 10  2022-02-07 04:47:23.654502
# 11  2022-02-07 04:47:24.197681
# 12  2022-02-07 04:47:24.285275
# 13  2022-02-07 04:47:24.980761
# 14  2022-02-07 04:47:27.089663
# 15  2022-02-07 04:47:32.787691
# 16  2022-02-07 04:47:39.982291
# 17  2022-02-07 04:47:41.628919
# 18  2022-02-07 04:47:42.853531
# 19  2022-02-07 04:47:43.089014
# 20  2022-02-07 04:47:43.159806
# 21  2022-02-07 04:47:43.297806
# 22  2022-02-07 04:47:43.378578
# 23  2022-02-07 04:47:43.857061
# 24  2022-02-07 04:47:45.349441
# 25  2022-02-07 04:47:46.226999
# 26  2022-02-07 04:47:46.377577
# 27  2022-02-07 04:47:46.615878
# 28  2022-02-07 04:47:47.422339
# 29  2022-02-07 04:47:49.110628
# 30  2022-02-07 04:47:56.794721
# 31  2022-02-07 04:47:59.445498
# 32  2022-02-07 04:48:01.816152
# 33  2022-02-07 04:48:03.501423
# 34  2022-02-07 04:48:03.609801
# 35  2022-02-07 04:48:04.597070
# 36  2022-02-07 04:48:04.619419
# 37  2022-02-07 04:48:05.746051
# 38  2022-02-07 04:48:07.496883
# 39  2022-02-07 04:48:08.539294
# 40  2022-02-07 04:48:08.747060
# 41  2022-02-07 04:48:09.526865
# 42  2022-02-07 04:48:09.725005
# 43  2022-02-07 04:48:10.083866
# 44  2022-02-07 04:48:11.441012
# 45  2022-02-07 04:48:12.682576
# 46  2022-02-07 04:48:13.949991
# 47  2022-02-07 04:48:16.214605
# 48  2022-02-07 04:48:34.663331
# 49  2022-02-07 04:49:22.998616
# 50  2022-02-07 04:49:39.909562
# 51  2022-02-07 04:50:15.712929
# 52  2022-02-07 04:50:25.657988
# 53  2022-02-07 04:50:28.137316
# 54  2022-04-13 13:33:24.070815
# 55  2022-04-13 13:33:26.186161
# 56  2022-04-13 13:34:16.687649
# 57  2022-04-13 13:34:18.316242
# 58  2022-04-13 13:34:19.705189
# 59  2022-04-13 13:34:20.001461
# 60  2022-04-13 13:34:20.357624
# 61  2022-04-13 13:34:21.801291
# 62  2022-04-13 13:34:27.429135
# 63  2022-04-13 13:34:27.670890
# 64  2022-04-13 22:14:13.520665
# 65  2022-04-13 22:14:15.707830
# 66  2022-04-13 22:14:16.681310
# 67  2022-04-13 22:14:19.199018
# 68  2022-04-13 22:14:19.756711
# 69  2022-04-13 22:14:20.364978
# 70  2022-04-13 22:14:21.415000
# 71  2022-04-13 22:14:23.534091
# 72  2022-04-13 22:14:32.366496
# 73  2022-04-13 22:14:34.778557
# 74  2022-04-13 22:14:48.538023
# 75  2022-04-13 22:14:49.210306
# 76  2022-04-13 22:15:20.153936
# 77  2022-04-13 22:15:23.727380
# 78  2022-04-13 22:15:24.827646
# 79  2022-04-13 22:15:25.145995
# 80  2022-04-13 22:15:27.062602
# 81  2022-04-13 22:15:37.658461
# 82  2022-04-13 22:15:38.984532
# 83  2022-04-13 22:15:49.739782
# 84  2022-04-13 22:15:54.560279
# 85  2022-04-13 22:15:56.967805
# 86  2022-04-13 22:16:11.071640
# 87  2022-04-13 22:16:11.975892
# 88  2022-04-13 22:16:19.685611
# 89  2022-04-13 22:16:25.601246
# 90  2022-04-13 22:16:25.609560
# 91  2022-04-13 22:16:27.853192
# 92  2022-04-15 09:38:55.205814
# 93  2022-04-15 09:38:59.893889
# 94  2022-04-15 09:39:02.689050
# 95  2022-04-16 07:38:50.928331
# 96  2022-04-16 07:39:00.362284
# 97  2022-04-16 07:39:00.983246
# 98  2022-04-16 07:39:19.007960
# 99  2022-04-16 07:39:39.687545
# 100 2022-04-16 07:39:40.060505
# 101 2022-04-16 07:40:37.896839
# 102 2022-04-16 07:40:39.145986
# 103 2022-04-16 07:40:41.753788
# 104 2022-04-16 07:40:42.368504
# 105 2022-04-16 07:40:43.362445
# 106 2022-04-16 07:40:45.196280
# 107 2022-04-16 07:40:57.667078
# 108 2022-04-16 07:40:58.203758
# 109 2022-04-16 07:41:28.259798
# 110 2022-04-16 07:41:30.765669
# 111 2022-04-16 07:41:43.400831
# 112 2022-04-16 07:41:45.835750
# 113 2022-04-16 07:41:47.858271
# 114 2022-04-16 07:41:49.761751
# 115 2022-04-16 07:41:50.988203
# 116 2022-04-16 07:41:51.137344
# 117 2022-04-16 07:41:52.501330
# 118 2022-04-16 07:41:53.697328
# 119 2022-04-16 07:41:54.318073
# 120 2022-04-16 07:41:56.207958
# 121 2022-04-16 07:42:07.962781
# 122 2022-04-16 07:42:10.354528
# 123 2022-04-16 07:51:56.903729
# 124 2022-04-16 07:51:58.643490
# 125 2022-04-16 07:51:59.549752
# 126 2022-04-16 07:52:00.796828
# 127 2022-04-16 07:52:01.138459
# 128 2022-04-16 07:52:01.604965
# 129 2022-04-16 07:52:03.392092
# 130 2022-04-16 07:52:10.139333
# 131 2022-04-16 07:52:12.614588
# 132 2022-04-16 07:53:01.116852
# 133 2022-04-16 07:53:01.739474
# 134 2022-04-16 07:53:17.817787
# 135 2022-04-16 07:53:18.586062
# 136 2022-04-16 07:53:47.443105
# 137 2022-04-16 07:53:47.875800
# 138 2022-04-16 07:53:52.542157
# 139 2022-04-16 07:53:53.371402
# 140 2022-05-18 22:28:28.631305
# 141 2022-05-18 22:28:31.661198
# 142 2022-06-02 22:14:13.023414
# 143 2022-06-02 22:14:17.277218
# 144 2022-06-12 16:48:32.547441
# 145 2022-06-12 16:48:33.325609
# 146 2022-06-12 16:48:37.306392
# 147 2022-06-12 16:48:42.680451
# 148 2022-06-12 16:48:43.970429
# 149 2022-06-12 16:48:52.401445
# 150 2022-06-12 16:48:53.771286
# 151 2022-06-12 16:48:54.950950
# 152 2022-06-12 16:48:55.245637
# 153 2022-06-12 16:48:56.156558
# 154 2022-06-12 16:48:56.569324
# 155 2022-06-12 16:48:57.100044
# 156 2022-06-12 16:48:57.802588
# 157 2022-06-12 16:48:58.955769
# 158 2022-06-12 16:49:00.697103
# 159 2022-06-12 16:49:06.203236
# 160 2022-06-12 16:49:06.538448
# 161 2022-06-12 16:49:23.140955
# 162 2022-06-12 16:49:23.968834
# 163 2022-06-12 16:49:31.659898
# 164 2022-06-12 16:49:31.972477
# 165 2022-06-12 16:49:35.212002
# 166 2022-06-12 16:49:37.285069
# 167 2022-06-12 16:49:49.323191
# 168 2022-06-12 16:49:52.616122
# 169 2022-06-12 16:49:53.099574
# 170 2022-06-12 16:49:54.387231
# 171 2022-06-12 16:49:55.076632
# 172 2022-06-12 16:49:55.585796
# 173 2022-06-12 16:49:55.918873
# 174 2022-06-12 16:49:56.804721
# 175 2022-06-12 16:49:58.501940
# 176 2022-06-12 16:50:02.350561
# 177 2022-06-12 16:50:05.571598
# 178 2022-06-12 16:50:12.872689
# 179 2022-06-12 16:50:20.373327
# 180 2022-06-12 16:50:35.738693
# 181 2022-06-12 16:50:35.954897
# 182 2022-06-12 16:51:27.678070
# 183 2022-06-12 16:51:58.188974
# 184 2022-06-12 16:52:30.224544
# 185 2022-06-12 16:52:39.502736
# 186 2022-06-12 16:52:41.697022
# 187 2022-06-12 16:52:51.346940
# 188 2022-06-12 16:53:06.529103
# 189 2022-06-12 16:53:06.786972
# 190 2022-06-12 16:56:39.434670
# 191 2022-06-12 16:56:51.999813
# 192 2022-06-12 16:56:53.905287
# 193 2022-06-12 16:57:04.315299
# 194 2022-06-12 16:57:07.908605
# 195 2022-06-12 16:57:10.578002
# 196 2022-06-12 16:57:31.049913
# 197 2022-06-12 16:57:33.139837
# 198 2022-06-22 22:09:32.050952
# 199 2022-06-22 22:09:35.636502
# 200 2022-06-22 22:10:04.572432
# 201 2022-06-22 22:10:07.991327
# 202 2022-06-22 22:10:33.194900
# 203 2022-06-22 22:10:35.180608
# 204 2022-06-22 22:10:55.700696
# 205 2022-06-22 22:10:57.681651
# 206 2022-07-06 17:24:55.687960
# 207 2022-07-06 17:24:59.696383
# 208 2022-07-06 17:25:11.198377
# 209 2022-07-06 17:25:13.218867
# 210 2022-07-06 17:25:24.102198
# 211 2022-07-06 17:25:25.400452
# 212 2022-08-16 10:52:26.700735
# 213 2022-08-16 10:52:47.009827
# 214 2022-08-16 10:52:47.565198
# 215 2022-08-16 10:52:48.658738
# 216 2022-08-16 10:52:51.582204
# 217 2022-08-16 10:52:54.165909
# 218 2022-08-16 10:52:57.060787
# 219 2022-08-16 10:53:03.061769
# 220 2022-08-16 10:53:12.136065
# 221 2022-08-16 10:53:35.344045
# 222 2022-08-16 10:53:35.732135
# 223 2022-08-16 10:53:49.325133
# 224 2022-08-16 10:54:07.033370
# 225 2022-08-16 10:54:37.520065
# 226 2022-08-16 10:54:47.018711
# 227 2022-08-16 10:54:48.110420
# 228 2022-08-16 10:55:24.048614
# 229 2022-08-16 10:55:31.246424
# 230 2022-11-17 20:37:58.617923
# 231 2022-11-17 20:38:47.550184
# 232 2022-11-17 20:38:49.348355
# 233 2022-11-17 20:38:53.947216
# 234 2022-11-17 20:39:02.807588
# 235 2022-11-17 20:39:11.372048
# 236 2022-11-17 20:39:12.200748
# 237 2022-11-17 20:39:33.429886
# 238 2022-11-17 20:39:36.592640
# 239 2022-11-17 20:39:37.211034
# 240 2022-11-17 20:39:37.319187
# 241 2022-11-17 20:39:38.419610
# 242 2022-11-17 20:39:38.459892
# 243 2022-11-17 20:39:39.718239
# 244 2022-11-17 20:39:39.759210
# 245 2022-11-17 20:39:40.205215
# 246 2022-11-17 20:39:40.552727
# 247 2022-11-17 20:39:41.028962
# 248 2022-11-17 20:39:41.377146
# 249 2022-11-17 20:39:41.466191
# 250 2022-11-17 20:39:42.034666
# 251 2022-11-17 20:39:42.038713
# 252 2022-11-17 20:39:44.892425
# 253 2022-11-17 20:39:59.357181
# 254 2022-11-17 20:40:00.586118
# 255 2022-11-17 20:40:48.346764
# 256 2022-11-17 20:40:53.272657
# 257 2022-11-17 20:40:54.766496
# 258 2022-11-17 20:40:58.460891
# 259 2022-11-17 20:41:00.583420
# 260 2022-11-17 20:41:12.835030
# 261 2022-11-17 20:41:53.304263
# 262 2022-11-17 20:42:21.429143
# 263 2022-11-17 20:42:49.650891
#
#                                                                                                                  URL
# 0    @user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_425596_profile
# 1                                                                                              api/users/id/template
# 2                                                                                                           @user_id
# 3                                                                                              api/users/id/template
# 4                                                                                                                NaN
# 5                                                                                                                NaN
# 6                                                                                                         suggest?q=
# 7                                                                                                        suggest?q=ㅠ
# 8                                                                                                      suggest?q=bio
# 9                                                                                                suggest?q=bioninfor
# 10                                                                                             suggest?q=bioninforma
# 11                                                                                         suggest?q=bioninformatics
# 12                                                                                                      suggest?q=bi
# 13                                                                                   search?keywords=bioninformatics
# 14                                                                   api/search/template?keywords=bioninformatics&q=
# 15                                                                                                               NaN
# 16                                                                                                        suggest?q=
# 17                                                                                                       suggest?q=b
# 18                                                                                                    suggest?q=bion
# 19                                                                                                      suggest?q=bi
# 20                                                                                                     suggest?q=bio
# 21                                                                                                  suggest?q=bionin
# 22                                                                                                   suggest?q=bioni
# 23                                                                                                 suggest?q=bionino
# 24                                                                                               suggest?q=bioninfor
# 25                                                                                             suggest?q=bioninforma
# 26                                                                                              suggest?q=bioninform
# 27                                                                                         suggest?q=bioninformatics
# 28                                                                                   search?keywords=bioninformatics
# 29                                                                   api/search/template?keywords=bioninformatics&q=
# 30                                                                                                               NaN
# 31                                                                                                               NaN
# 32                                                                                                        suggest?q=
# 33                                                                                                       suggest?q=b
# 34                                                                                                               NaN
# 35                                                                                                     suggest?q=bio
# 36                                                                                                      suggest?q=bi
# 37                                                                                                        suggest?q=
# 38                                                                                                       suggest?q=b
# 39                                                                                                      suggest?q=bi
# 40                                                                                                     suggest?q=bio
# 41                                                                                                   suggest?q=bioin
# 42                                                                                                    suggest?q=bioi
# 43                                                                                                suggest?q=bioinfor
# 44                                                                                              suggest?q=bioinforma
# 45                                                                                          suggest?q=bioinformatics
# 46                                                                                    search?keywords=bioinformatics
# 47                                                                    api/search/template?keywords=bioinformatics&q=
# 48                                                                                                  jobs/id/id_title
# 49                                                                                         companies/company_id/jobs
# 50                                                                           api/jobs/id/other_jobs?offset=0&limit=5
# 51                                                                   api/companies/id/member_list?oneline=1&offset=3
# 52                                                                                                          @user_id
# 53                                                                                             api/users/id/template
# 54                                                                                                          @user_id
# 55                                                                                             api/users/id/template
# 56                                                                                                        suggest?q=
# 57                                                                                                       suggest?q=W
# 58                                                                                                    suggest?q=지니너스
# 59                                                                                                    suggest?q=지니너스
# 60                                                                                              search?keywords=지니너스
# 61                                                                              api/search/template?keywords=지니너스&q=
# 62                                                                                              companies/company_id
# 63                                                                                             api/companies/id/view
# 64                                                                                                          @user_id
# 65                                                                                                        suggest?q=
# 66                                                                                             api/users/id/template
# 67                                                                                                       suggest?q=김
# 68                                                                                                      suggest?q=김ㅁ
# 69                                                                                                     suggest?q=김민재
# 70                                                                                               search?keywords=김민재
# 71                                                                               api/search/template?keywords=김민재&q=
# 72                                                                                            people?keywords=김민재&q=
# 73                                                                         api/people/template?keywords=김민재&page=&q=
# 74                                                                                                          @user_id
# 75                                                                                             api/users/id/template
# 76                                                                                                        suggest?q=
# 77                                                                                                       suggest?q=기
# 78                                                                                                     suggest?q=김나영
# 79                                                                                               search?keywords=김나영
# 80                                                                               api/search/template?keywords=김나영&q=
# 81                                                                                                            search
# 82                                                                                            api/search/template?q=
# 83                                                                             api/search/template?keywords=@지니너스&q=
# 84                                                                                                          @user_id
# 85                                                                                             api/users/id/template
# 86                                                                                              companies/company_id
# 87                                                                                             api/companies/id/view
# 88                                                                                                        suggest?q=
# 89                                                                                           search?keywords=마이크로바이옴
# 90                                                                                                 suggest?q=마이크로바이옴
# 91                                                                           api/search/template?keywords=마이크로바이옴&q=
# 92                                                               @user_id/undefined?offset=undefined&_=1650015535862
# 93                                                                                                          @user_id
# 94                                                                                             api/users/id/template
# 95                                                                                                               NaN
# 96                                                                                              companies/company_id
# 97                                                                                             api/companies/id/view
# 98                                                                                         companies/company_id/jobs
# 99                                                                                                  jobs/id/id_title
# 100                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 101                                                                                        companies/company_id/jobs
# 102                                                                                                       suggest?q=
# 103                                                                                                      suggest?q=ㅇ
# 104                                                                                                 suggest?q=docker
# 105                                                                                           search?keywords=docker
# 106                                                                           api/search/template?keywords=docker&q=
# 107                                                                                                 jobs/id/id_title
# 108                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 109                                                                                                         @user_id
# 110                                                                                            api/users/id/template
# 111                                                                                                       suggest?q=
# 112                                                                                                      suggest?q=@
# 113                                                                                                suggest?q=@wlslsj
# 114                                                                                                  suggest?q=@akzm
# 115                                                                                                     suggest?q=@a
# 116                                                                                                      suggest?q=ㅁ
# 117                                                                                                     suggest?q=@a
# 118                                                                                                  suggest?q=@마크로젠
# 119                                                                                            search?keywords=@마크로젠
# 120                                                                            api/search/template?keywords=@마크로젠&q=
# 121                                                                                                         @user_id
# 122                                                                                            api/users/id/template
# 123                                                                                                       suggest?q=
# 124                                                                                                      suggest?q=@
# 125                                                                                                     suggest?q=@ㅈ
# 126                                                                                                  suggest?q=@지니너스
# 127                                                                                                  suggest?q=@지니너스
# 128                                                                                            search?keywords=@지니너스
# 129                                                                            api/search/template?keywords=@지니너스&q=
# 130                                                                                                         @user_id
# 131                                                                                            api/users/id/template
# 132                                                                                             companies/company_id
# 133                                                                                            api/companies/id/view
# 134                                                                                                         @user_id
# 135                                                                                            api/users/id/template
# 136                                                                                             companies/company_id
# 137                                                                                            api/companies/id/view
# 138                                                                                            people?company=129582
# 139                                                                      api/people/template?company=129582&page=&q=
# 140  @user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_384600_profile
# 141                                                                                            api/users/id/template
# 142  @user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_338683_profile
# 143                                                                                            api/users/id/template
# 144                                                                                                    signup/detail
# 145                                                                                                signup/step1/name
# 146                                                                                                           signup
# 147                                                                                                              NaN
# 148                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 149                                                                                                       suggest?q=
# 150                                                                                                      suggest?q=ㅠ
# 151                                                                                                    suggest?q=bio
# 152                                                                                                  suggest?q=bioin
# 153                                                                                                suggest?q=bioinfo
# 154                                                                                               suggest?q=bioinfor
# 155                                                                                             suggest?q=bioinforma
# 156                                                                                         suggest?q=bioinformatics
# 157                                                                                   search?keywords=bioinformatics
# 158                                                                   api/search/template?keywords=bioinformatics&q=
# 159                                                                                             companies/company_id
# 160                                                                                            api/companies/id/view
# 161                                                                                             people?company=24720
# 162                                                                       api/people/template?company=24720&page=&q=
# 163                                                                                             companies/company_id
# 164                                                                                            api/companies/id/view
# 165                                                                                                         @user_id
# 166                                                                                            api/users/id/template
# 167                                                                                                       suggest?q=
# 168                                                                                                      suggest?q=b
# 169                                                                                                    suggest?q=bio
# 170                                                                                              suggest?q=bioinform
# 171                                                                                             suggest?q=bioinforma
# 172                                                                                            suggest?q=bioinformat
# 173                                                                                         suggest?q=bioinformatics
# 174                                                                                   search?keywords=bioinformatics
# 175                                                                   api/search/template?keywords=bioinformatics&q=
# 176                                                                                                             jobs
# 177                                                                                      api/jobs/job_title?page=&q=
# 178                                                              api/jobs/job_title?keywords=bioinformatics&page=&q=
# 179                                                                                        companies/company_id/jobs
# 180                                                                                                 jobs/id/id_title
# 181                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 182                                                                                        companies/company_id/jobs
# 183                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 184                                                                  api/companies/id/member_list?oneline=1&offset=3
# 185                                                                                                         @user_id
# 186                                                                                            api/users/id/template
# 187                                                                                        companies/company_id/jobs
# 188                                                                                                 jobs/id/id_title
# 189                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 190                                                                                        companies/company_id/jobs
# 191                                                                                                         @user_id
# 192                                                                                            api/users/id/template
# 193                                                                                        companies/company_id/jobs
# 194                                                                                                         @user_id
# 195                                                                                            api/users/id/template
# 196                                                                                                             jobs
# 197                                                                                      api/jobs/job_title?page=&q=
# 198  @user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_415458_profile
# 199                                                                                            api/users/id/template
# 200  @user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_420864_profile
# 201                                                                                            api/users/id/template
# 202  @user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_342499_profile
# 203                                                                                            api/users/id/template
# 204  @user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_412864_profile
# 205                                                                                            api/users/id/template
# 206  @user_id?utm_source=notification&utm_medium=email&utm_campaign=recommend_people&utm_content=user_375943_profile
# 207                                                                                            api/users/id/template
# 208                                                                                                         @user_id
# 209                                                                                            api/users/id/template
# 210                                                                                                         @user_id
# 211                                                                                            api/users/id/template
# 212                                                                                                              NaN
# 213                                                                                                       suggest?q=
# 214                                                                                                      suggest?q=ㅇ
# 215                                                                                                      suggest?q=b
# 216                                                                                                             jobs
# 217                                                                                      api/jobs/job_title?page=&q=
# 218                                                                                                       suggest?q=
# 219                                                             api/jobs/job_title?keywords=bioinformatics\&page=&q=
# 220                                                                                        companies/company_id/jobs
# 221                                                                                             companies/company_id
# 222                                                                                            api/companies/id/view
# 223                                                                                        companies/company_id/jobs
# 224                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 225                                                                                        companies/company_id/jobs
# 226                                                                                                 jobs/id/id_title
# 227                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 228                                                                                        companies/company_id/jobs
# 229                                                                                                         @user_id
# 230                                                                                        companies/company_id/jobs
# 231                                                                                             companies/company_id
# 232                                                                                            api/companies/id/view
# 233                                                                            api/companies/id/member_list?offset=6
# 234                                                                                        companies/company_id/jobs
# 235                                                                                                 jobs/id/id_title
# 236                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 237                                                                                                       suggest?q=
# 238                                                                                                      suggest?q=ㅅ
# 239                                                                                                      suggest?q=사
# 240                                                                                                      suggest?q=새
# 241                                                                                                      suggest?q=생
# 242                                                                                                     suggest?q=생ㅁ
# 243                                                                                                     suggest?q=생물
# 244                                                                                                    suggest?q=생물ㅈ
# 245                                                                                                    suggest?q=생물저
# 246                                                                                                    suggest?q=생물정
# 247                                                                                                  suggest?q=생물정ㅂㆍ
# 248                                                                                                   suggest?q=생물정ㅂ
# 249                                                                                                   suggest?q=생물정보
# 250                                                                                                  suggest?q=생물정보학
# 251                                                                                            search?keywords=생물정보학
# 252                                                                            api/search/template?keywords=생물정보학&q=
# 253                                                                                             companies/company_id
# 254                                                                                            api/companies/id/view
# 255                                                                                        companies/company_id/jobs
# 256                                                                                             companies/company_id
# 257                                                                                            api/companies/id/view
# 258                                                                                                             jobs
# 259                                                                                      api/jobs/job_title?page=&q=
# 260                                                              api/jobs/job_title?keywords=bioinformatics&page=&q=
# 261                                                                                        companies/company_id/jobs
# 262                                                                          api/jobs/id/other_jobs?offset=0&limit=5
# 263                                                                                        companies/company_id/jobs

# %%
# 설정을 기본값으로 리셋
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.width')
pd.reset_option('display.max_colwidth')

# %% [markdown]
# # 전처리 데이터 추출

# %%
# UTM 파라미터 값을 가진 행만 추출
utm_2022_df = log_2022_df[log_2022_df['URL'].str.contains('utm_', na=False)]

# 'api/'로 시작하는 행만 추출
api_2022_df = log_2022_df[log_2022_df['URL'].str.startswith('api/', na=False)]

# %%
utm_2022_df.to_csv('utm_2022_df.csv', index=False, encoding='utf-8-sig')
api_2022_df.to_csv('api_2022_df.csv', index=False, encoding='utf-8-sig')

# %%
from urllib.parse import urlparse, parse_qs
from collections import Counter

#  URL 의미 기반 태깅 함수
def map_funnel_stage(url):
    url = str(url).lower()

    if pd.isna(url) or url.strip() == '':
        return '기타'

    if 'search' in url or 'keywords' in url or 'suggest' in url or 'q=' in url:
        return '검색'
    elif 'job_title' in url or 'jobs/id' in url:
        return '공고 보기'
    elif 'companies' in url or 'company_id' in url:
        return '기업 보기'
    elif 'template' in url or 'career' in url or 'experience' in url or 'profile' in url:
        return '이력서 작성'
    elif 'apply/step' in url:
        return '지원 시작'
    elif 'applications' in url:
        return '지원 완료'
    elif 'notifications/mark_read' in url:
        return '알림 확인'
    elif '@user_id' in url or 'follower' in url or 'following' in url:
        return '유저 프로필'
    elif 'setting' in url or 'timeline' in url:
        return '설정'
    elif 'signup' in url or 'password_reset' in url:
        return '회원가입'
    else:
        return '기타'

# URL 쿼리 파라미터 추출
def extract_query_keywords(url):
    try:
        parsed = urlparse(str(url))
        query = parse_qs(parsed.query)
        keywords = []
        for k, v in query.items():
            if k in ['q', 'keywords', 'name', 'type', 'job', 'offset']:
                keywords.append(f"{k}={','.join(v)}")
        return '&'.join(keywords)
    except:
        return ''

# 의미 기반 컬럼 생성
log_2022_df['funnel_stage'] = log_2022_df['URL'].apply(map_funnel_stage)
log_2022_df['query_tags'] = log_2022_df['URL'].apply(extract_query_keywords)

# 분석용 테이블 구성
behavior_table = log_2022_df[['user_uuid', 'timestamp', 'URL', 'funnel_stage', 'query_tags']].sort_values(by=['user_uuid', 'timestamp'])
behavior_table = behavior_table[
    ~behavior_table['URL'].str.contains('utm', case=False, na=False) &
    ~behavior_table['URL'].str.startswith('api/', na=False)
].reset_index(drop=True)

# %%
behavior_table.to_csv('log_2022_df.csv', index=False, encoding='utf-8-sig')
